# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open("../artifacts/model.pkl", "rb") as f:
    pipeline = pickle.load(f)

model = pipeline.named_steps['model']
preprocessor = pipeline.named_steps['preprocessor']

feature_names = preprocessor.get_feature_names_out()
importance = model.feature_importances_

feature_importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': importance
}).sort_values(by='importance', ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(data=feature_importance_df.head(15), x='importance', y='feature', palette='viridis')
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.show()
# Out:
# /var/folders/n0/5m_fhb1d7xdbhfkz54jbzbnh0000gn/T/ipykernel_13668/2717956770.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=feature_importance_df.head(15), x='importance', y='feature', palette='viridis')

# %%
feature_importance_df.head(15)
# Out:
#                                               feature  importance
# 5                                            num__crr    0.108206
# 74                                     cat__innings_1    0.045381
# 2                                   num__wickets_left    0.032646
# 25                  cat__venue_MA Chidambaram Stadium    0.031563
# 4                                  num__current_score    0.028539
# 26  cat__venue_Maharaja Yadavindra Singh Internati...    0.025290
# 38                 cat__venue_Sharjah Cricket Stadium    0.023077
# 51             cat__batting_team_Lucknow Super Giants    0.022362
# 20  cat__venue_Himachal Pradesh Cricket Associatio...    0.022237
# 63                   cat__bowling_team_Gujarat Titans    0.022109
# 39                    cat__venue_Sheikh Zayed Stadium    0.021260
# 12                       cat__venue_Brabourne Stadium    0.020999
# 48                   cat__batting_team_Gujarat Titans    0.019698
# 28                   cat__venue_Narendra Modi Stadium    0.019037
# 11  cat__venue_Bharat Ratna Shri Atal Bihari Vajpa...    0.018321
